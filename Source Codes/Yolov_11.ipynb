# %%
### 1. Mount Google Drive ###

from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
### 2. Define root directory ###

ROOT_DIR = '/content/gdrive/MyDrive/YOLOV-11p'

# %%
from zipfile import ZipFile
import os

# Specify the path to the zip file and the extraction directory
zip_file_path = '/content/gdrive/MyDrive/YOLOV-11p/Data.zip'
extracted_dir_path = '/content/data'

# Create the extraction directory if it doesn't exist
os.makedirs(extracted_dir_path, exist_ok=True)

# Extract the contents of the zip file
with ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extracted_dir_path)

# List the files in the extraction directory
extracted_files = os.listdir(extracted_dir_path)
print(f"Files extracted to {extracted_dir_path}: {extracted_files}")
# Out:
# Files extracted to /content/data: ['Data']

# %%
import sys
sys.path.append('/content/gdrive/MyDrive/YOLOV-11p/ultralytics-main')

# %%
### 4. Train model ###

from ultralytics import YOLO


# Load a model
model = YOLO('yolo11.yaml').load('yolo11n.pt')  # load pre trained model

# Use the model
results = model.train(data=os.path.join(ROOT_DIR, "google_colab_config.yaml"), epochs=100, imgsz=640)  # train the model

# %%
### 5. Copy results ###

import shutil

# Replace 'folder_path' with the path to your folder
folder_path = '/content/runs/segment/train'

# Replace 'zip_file_path' with the desired path for the zip file
zip_file_path = '/content/Runs'

shutil.make_archive(zip_file_path, 'zip', folder_path)
# Out:
# '/content/Runs.zip'

# %%
# Replace 'zip_file_path' with the path to your zip file
shutil.move('/content/Runs.zip', '/content/gdrive/MyDrive/YOLOV-11p/Runs')
# Out:
# '/content/gdrive/MyDrive/YOLOV-11p/Runs/Runs.zip'
